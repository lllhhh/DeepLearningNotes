# %% [markdown]
# # 1.快速绘图

# %% [markdown]
# ## 1.1使用pyplot模块绘图

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 10, 1000)
y = np.sin(x)
z = np.cos(x**2)

plt.figure(figsize=(8,4))

plt.plot(x, y, label="$ sin(x) $", color= 'red', linewidth=2)
plt.plot(x, z, 'b--', label='$ cos(x^2) $')
plt.xlabel("Time(s)")
plt.ylabel("Volt")
plt.title("example")
plt.ylim(-1.2, 1.2)
plt.legend()
plt.show()
# Out:
# Object `plt.show()` not found.

# %% [markdown]
# ## 1.2面向对象方式绘图

# %%
# 绘制line
plt.figure(figsize=(4,3))
x = np.arange(0, 5, 0.1)
line = plt.plot(x,0.05*x*x) #plot返回一个列表

# %%
lines = plt.plot(x, np.sin(x), x, np.cos(x))

# %%
plt.setp(lines, color='r', linewidth=4.0)
# Out:
# [None, None, None, None]

# %% [markdown]
# ## 1.4绘制多子图

# %%
for idx, color in enumerate('rgbyck'):
    plt.subplot(321 + idx, facecolor=color)

# %%
plt.subplot(221)
plt.subplot(222)
plt.subplot(212)

# %%
plt.figure(1)
plt.figure(2)
ax1 = plt.subplot(121)
ax2 = plt.subplot(122)

x = np.linspace(0, 3, 100)
for i in range(1,5):
    plt.figure(1)
    plt.plot(x, np.exp(i*x/3))
    plt.sca(ax1)
    plt.plot(x,np.sin(i*x))
    plt.sca(ax2)
    plt.plot(x, np.cos(i*x))
# Out:
# ----------------------------------------------------------------------
# NameError                            Traceback (most recent call last)
# <ipython-input-42-70e4d8fa9ee2> in <module>
#       5
#       6 x = np.linspace(0, 3, 100)
# ----> 7 for i in xrange(5):
#       8     plt.figure(1)
#       9     plt.plot(x, np.exp(i*x/3))
#
# NameError: name 'xrange' is not defined
