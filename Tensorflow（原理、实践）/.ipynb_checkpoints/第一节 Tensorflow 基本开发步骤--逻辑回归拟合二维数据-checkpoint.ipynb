# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 准备数据

# %%
train_X = np.linspace(-1, 1, 100)
train_X.shape
# Out:
# (100,)

# %%
train_Y = 2 * train_X + np.random.randn(train_X.shape[0]) * 0.3  # y=2x
# Out:
# 100

# %%
plt.plot(train_X,train_Y,'ro',label='Origin data')
plt.legend()
plt.show()

# %% [markdown]
# ## 搭建模型
# ### 正向模型

# %%
# 占位符
X = tf.placeholder("float")
Y = tf.placeholder("float")

# 模型参数
W = tf.Variable(tf.random_normal([1]), name="weights")
b = tf.Variable(tf.zeros([1]),name="bias")

# 向前结构
z = tf.multiply(X,W) + b

# %% [markdown]
# ### 反向搭建模型

# %%
# 损失函数
cost = tf.reduce_mean(tf.square(Y - z))

#学习率
learning_rate = 0.01 

# 梯度下降 优化目标是最小化损失函数。 所以是minimize函数，并且把损失函数作为参数传递过去。
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)

# %% [markdown]
# ## 训练模型

# %%
# 初始化所有变量
init = tf.global_variables_initializer()
plotdata = {'batchsize':[],'loss':[]} # 存放

def moving_avarage(a, w=10):
    if len(a) < w:
        return a[:]
    return [val if idx < w else sum(a[(idx-w):idx]/w) for idx,val in enumerate(a)]

#定义参数
training_epochs = 20
display_step = 2

# 启动
with tf.Session() as sess:
    sess.run(init)
    
    # 想模型输入数据
    for epoch in range(training_epochs):
        for (x,y) in zip(train_X,train_Y):
            sess.run(optimizer,feed_dict={X:x,Y:y})
            
            # 显示训练的详细信息
        if epoch % display_step == 0:
            loss = sess.run(cost,feed_dict={X:train_X,Y:train_Y})
            print("Epoch:",epoch+1,"cost=",loss,"W=",sess.run(W),"b=",sess.run(b))
                
            if not(loss == "NA"):
                plotdata["batchsize"].append(epoch)
                plotdata["loss"].append(loss)
    
    # 可视化
    plotSesson(sess)
    
    print("Finished!")
    print("cost=", sess.run(cost,feed_dict={X:train_X,Y:train_Y}),"W=",sess.run(W),"b=",sess.run(b))
    
    # 使用模型
    print('x=0.2,z=',sess.run(z,feed_dict={X:0.2}))
# Out:
# Epoch: 1 cost= 0.73777413 W= [0.6354654] b= [0.3664667]
# Epoch: 3 cost= 0.1451602 W= [1.5278865] b= [0.12853509]
# Epoch: 5 cost= 0.09487942 W= [1.7700102] b= [0.0373804]
# Epoch: 7 cost= 0.091056846 W= [1.8328071] b= [0.01331206]
# Epoch: 9 cost= 0.090693265 W= [1.8490481] b= [0.00708014]
# Epoch: 11 cost= 0.090641096 W= [1.853247] b= [0.00546881]
# Epoch: 13 cost= 0.09063042 W= [1.8543326] b= [0.00505223]
# Epoch: 15 cost= 0.090627834 W= [1.8546132] b= [0.00494457]
# Epoch: 17 cost= 0.090627186 W= [1.8546864] b= [0.00491655]
# Epoch: 19 cost= 0.090627015 W= [1.8547051] b= [0.00490932]
# Finished!
# cost= 0.090626985 W= [1.854708] b= [0.00490813]
# x=0.2,z= [0.37584975]

# %% [markdown]
# ### 训练模型可视化

# %%
# 图形显示
def plotSesson(sess):
    plt.plot(train_X,train_Y,'ro',label='Original data')
    plt.plot(train_X,sess.run(W) * train_X + sess.run(b),label="FittedLine")
    plt.legend()
    plt.show()
    
    plotdata['avgloss'] = moving_avarage(plotdata['loss'])
    plt.figure()
    plt.subplot(211)
    plt.plot(plotdata['batchsize'],plotdata["avgloss"],'b--')
    plt.xlabel('Minibatch number')
    plt.ylabel('Loss')
    plt.title('Minibatch number vs. Training Loss')
    plt.show()

# %% [markdown]
# ## 了解TensorFlow开发的基本步骤
# > 1. 定义TensorFlow输入节点。
# 2. 定义“学习参数”的变量。
# 3. 定义“运算”。
# 4. 优化函数，优化目标。
# 5. 初始化所有变量。
# 6. 迭代所有参数到最优解。
# 7. 测试模型。
# 8. 使用模型。

# %% [markdown]
# ### 1.定义输入节点的方法
# 1. 通过占位符定义：一般使用这种方式。
# 2. 通过字典类型定义：一般用于输入比较多的情况。
# 3. 直接定义：一般很少使用。
#
#
# - 通过占位符定义
# 使用tf.placeholder函数:
# ___
# ```Python
# X = tf.placeholder("float")
# Y = tf.placeholder("float")
# ```
# ___
#
# - 通过字典类型定义输入节点
# ___
# ```Python
# #占位符
# inputdict={
#     'x':tf.placeholder("float")
#     'y':tf.placeholder("float")
# }
# ```
# ___
#
# - 直接定义输入节点
# ___
# ```Python
# #生成模拟数据
# train_X =np.float32( np.linspace(-1, 1, 100))
# train_Y = 2 * train_X + np.random.randn(*train_X.shape) * 0.3 # y=2x，但是加入了噪声
# #图形显示
# plt.plot(train_X, train_Y, 'ro', label='Original data')
# plt.legend()
# plt.show()
#
# # 模型参数
# W = tf.Variable(tf.random_normal([1]), name="weight")
# b = tf.Variable(tf.zeros([1]), name="bias")
# # 前向结构
# z = tf.multiply(W, train_X)+ b
# ```
# ___

# %% [markdown]
# ### 2. 定义“模型参数”的变量
# - 直接定义
# ___
# ```Python
# #模型参数
# W = tf.Variable(tf.random_normal([1]),name="weights")
# b = tf.Variable(tf.zeros([1]),name="bias")
# ```
# ___
# - 字典定义
# ___
# ```Python
# #模型参数
# paradict= {
#     'w':tf.Variable(tf.random_normal([1])),
#     'b':tf.Variable(tf.zeros([1]))
# }
# #
# z = tf.mutiply(X,paradict['w']) + paradict['b']
# ```
# ___

# %% [markdown]
# ### 3. 定义“运算”
# - 定义正向传播模型
# > 例如多层神经网络、卷积神经网络、循环神经网络及更深层次的GoogleNet、Resnet等，它们都是由神经元以不同的组合方式组成的网络结构。
# - 定义损失函数
# > 损失函数主要是计算“输出值”与“目标值”之间的误差，是配合反向传播使用的。为了在反向传播中可以找到最小值，要求该函数必须是“可导”的。

# %% [markdown]
# ### 4. 优化函数，优化目标
# > 在有了正向结构和损失函数后，就是通过优化函数来优化学习参数了，这个过程也是在反向传播中完成的。
# > 反向传播过程，就是沿着正向传播的结构向相反方向将误差传递过去。

# %% [markdown]
# ### 5. 初始化所有变量
# ___
# ```Python
# init = tf.global_variables_initializer()
# #启动Session
# with tf.Session() as sess:
#     sess.tun(init)
# ```
# ___
# > 使用tf.global_variables_initializer()函数初始化所有变量的步骤，必须在所有变量和OP定义完成之后。这样才能保证定义的内容有效，否则，初始化之后定义的变量和OP都无法使用Session中的run来进行算值。

# %% [markdown]
# ### 6. 迭代更新参数到最优解
# 在session中通过run来运算模型中的节点，在训练环节也是如此，只不过run里面放的是优化操作的OP，同时会在外层加上循环次数。
# ___
# ```Python
# for epoch in range(training_epochs):
#      for (x, y) in zip(train_X, train_Y):
#          sess.run(optimizer, feed_dict={X: x, Y: y})
# ```
# ___
# > 真正使用过程中会引入一个叫做MINIBATCH的概念进行迭代训练，即每次取一定量的数据同时放到网络中进行训练。

# %% [markdown]
# ### 7. 测试模型

# %% [markdown]
# ### 8. 使用模型
# > 使用模型也与测试模型类似，只不过是将损失值的节点换成输出的节点即可。一般会把生成的模型保存起来，再通过载入已有的模型来进行实际的使用。
